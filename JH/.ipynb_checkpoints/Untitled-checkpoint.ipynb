# %%
import pandas as pd 
import datetime 
import glob

# %%
data = pd.read_csv("../data/NYC_Citywide_Annualized_Calendar_Sales_Update.csv") 
data.head()
# Out:
#    BOROUGH  NEIGHBORHOOD           BUILDING CLASS CATEGORY  \
# 0        1     FINANCIAL           14  RENTALS - 4-10 UNIT
# 1        1   HARLEM-EAST          01  ONE FAMILY DWELLINGS
# 2        1   HARLEM-EAST   07  RENTALS - WALKUP APARTMENTS
# 3        1  MIDTOWN EAST  13  CONDOS - ELEVATOR APARTMENTS
# 4        1  MIDTOWN EAST  13  CONDOS - ELEVATOR APARTMENTS
#
#   TAX CLASS AS OF FINAL ROLL  BLOCK   LOT  EASE-MENT  \
# 0                         2A      7    38        NaN
# 1                          1   1643   122        NaN
# 2                          2   1643   123        NaN
# 3                          2   1320  4247        NaN
# 4                          2   1365  1526        NaN
#
#   BUILDING CLASS AS OF FINAL ROLL                 ADDRESS APARTMENT NUMBER  \
# 0                              S9         60 PEARL STREET              NaN
# 1                              A4     155 EAST 115 STREET              NaN
# ...

# %%
data.count()
# Out:
# BOROUGH                            345059
# NEIGHBORHOOD                       345059
# BUILDING CLASS CATEGORY            345059
# TAX CLASS AS OF FINAL ROLL         341199
# BLOCK                              345059
# LOT                                345059
# EASE-MENT                               0
# BUILDING CLASS AS OF FINAL ROLL    341199
# ADDRESS                            345059
# APARTMENT NUMBER                    74790
# ZIP CODE                           345044
# RESIDENTIAL UNITS                  329081
# COMMERCIAL UNITS                   329081
# TOTAL UNITS                        329081
# LAND SQUARE FEET                   329079
# GROSS SQUARE FEET                  329082
# YEAR BUILT                         339532
# TAX CLASS AT TIME OF SALE          345059
# BUILDING CLASS AT TIME OF SALE     345059
# SALE PRICE                         345059
# SALE DATE                          345059
# Latitude                           334109
# ...

# %%
data['SALEDATE'] = pd.to_datetime(data['SALE DATE'], format="%m/%d/%Y")
data.head()
# Out:
#    BOROUGH  NEIGHBORHOOD           BUILDING CLASS CATEGORY  \
# 0        1     FINANCIAL           14  RENTALS - 4-10 UNIT
# 1        1   HARLEM-EAST          01  ONE FAMILY DWELLINGS
# 2        1   HARLEM-EAST   07  RENTALS - WALKUP APARTMENTS
# 3        1  MIDTOWN EAST  13  CONDOS - ELEVATOR APARTMENTS
# 4        1  MIDTOWN EAST  13  CONDOS - ELEVATOR APARTMENTS
#
#   TAX CLASS AS OF FINAL ROLL  BLOCK   LOT  EASE-MENT  \
# 0                         2A      7    38        NaN
# 1                          1   1643   122        NaN
# 2                          2   1643   123        NaN
# 3                          2   1320  4247        NaN
# 4                          2   1365  1526        NaN
#
#   BUILDING CLASS AS OF FINAL ROLL                 ADDRESS APARTMENT NUMBER  \
# 0                              S9         60 PEARL STREET              NaN
# 1                              A4     155 EAST 115 STREET              NaN
# ...

# %%
data1 = data.drop(columns=['TAX CLASS AS OF FINAL ROLL','EASE-MENT','BUILDING CLASS AS OF FINAL ROLL','Latitude', 'Longitude', 'Community Board','Council District',
                        'Census Tract','BIN','BBL','NTA','SALE DATE', 'TAX CLASS AT TIME OF SALE'])
data1.head()
# Out:
#    BOROUGH  NEIGHBORHOOD           BUILDING CLASS CATEGORY  BLOCK   LOT  \
# 0        1     FINANCIAL           14  RENTALS - 4-10 UNIT      7    38
# 1        1   HARLEM-EAST          01  ONE FAMILY DWELLINGS   1643   122
# 2        1   HARLEM-EAST   07  RENTALS - WALKUP APARTMENTS   1643   123
# 3        1  MIDTOWN EAST  13  CONDOS - ELEVATOR APARTMENTS   1320  4247
# 4        1  MIDTOWN EAST  13  CONDOS - ELEVATOR APARTMENTS   1365  1526
#
#                   ADDRESS APARTMENT NUMBER  ZIP CODE  RESIDENTIAL UNITS  \
# 0         60 PEARL STREET              NaN   10004.0                3.0
# 1     155 EAST 115 STREET              NaN   10029.0                1.0
# 2     157 EAST 115 STREET              NaN   10029.0               12.0
# 3  211 EAST 46TH   STREET              33J   10017.0                1.0
# 4  400 EAST 54TH   STREET              30H   10022.0                1.0
#
#    COMMERCIAL UNITS  TOTAL UNITS LAND SQUARE FEET GROSS SQUARE FEET  \
# ...

# %%
data1.to_csv('data/data.csv')

# %%
data_out = pd.read_csv("../data/out.csv")

# %%
data_out.head()
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT   BLOCK  \
# 0      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3030.0
# 1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3030.0
# 2      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3030.0
# 3      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3039.0
# 4      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3039.0
#
#     LOT  EASE-MENT BUILDING CLASS AT PRESENT                 ADDRESS  \
# 0  65.0        NaN                        A1        4455 PARK AVENUE
# 1  67.0        NaN                        A1        4451 PARK AVENUE
# 2  70.0        NaN                        A1        4445 PARK AVENUE
# 3  29.0        NaN                        A9  2327 WASHINGTON AVENUE
# 4  29.0        NaN                        A9     2327 WASHINGTON AVE
#
#   APARTMENT NUMBER  ...  RESIDENTIAL UNITS COMMERCIAL UNITS  TOTAL UNITS  \
# ...

# %%
data_out.count()
# Out:
# BOROUGH                           70870
# NEIGHBORHOOD                      70870
# BUILDING CLASS CATEGORY           70870
# TAX CLASS AT PRESENT              70840
# BLOCK                             70870
# LOT                               70870
# EASE-MENT                             0
# BUILDING CLASS AT PRESENT         70840
# ADDRESS                           70870
# APARTMENT NUMBER                  15847
# ZIP CODE                          70868
# RESIDENTIAL UNITS                 54507
# COMMERCIAL UNITS                  42581
# TOTAL UNITS                       56366
# LAND SQUARE FEET                  40722
# GROSS SQUARE FEET                 40722
# YEAR BUILT                        65677
# TAX CLASS AT TIME OF SALE         70870
# BUILDING CLASS AT TIME OF SALE    70870
#  SALE PRICE                       70870
# SALE DATE                         70870
# dtype: int64

# %%
data_out['SALEDATE'] = pd.to_datetime(data_out['SALE DATE'], format="%m/%d/%Y")

# %%
start_date = '2020-01-01'
mask = (data_out['SALEDATE'] >= start_date)

# %%
data_out = data_out.loc[mask]
data_out.head()
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY TAX CLASS AT PRESENT   BLOCK  \
# 0      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3030.0
# 1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3030.0
# 4      2.0     BATHGATE  01 ONE FAMILY DWELLINGS                    1  3039.0
# 5      2.0     BATHGATE  02 TWO FAMILY DWELLINGS                    1  2912.0
# 8      2.0     BATHGATE  02 TWO FAMILY DWELLINGS                    1  2929.0
#
#      LOT  EASE-MENT BUILDING CLASS AT PRESENT                ADDRESS  \
# 0   65.0        NaN                        A1       4455 PARK AVENUE
# 1   67.0        NaN                        A1       4451 PARK AVENUE
# 4   29.0        NaN                        A9    2327 WASHINGTON AVE
# 5  130.0        NaN                        B1  482 CLAREMONT PARKWAY
# 8  114.0        NaN                        B1          3854 3 AVENUE
#
#   APARTMENT NUMBER  ...  COMMERCIAL UNITS TOTAL UNITS  LAND SQUARE FEET  \
# ...

# %%
data_out1 = data_out.drop(columns=['TAX CLASS AT PRESENT','EASE-MENT', 'SALE DATE'])
data_out1.head()
# Out:
#    BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY   BLOCK    LOT  \
# 0      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   65.0
# 1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   67.0
# 4      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3039.0   29.0
# 5      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2912.0  130.0
# 8      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2929.0  114.0
#
#   BUILDING CLASS AT PRESENT                ADDRESS APARTMENT NUMBER  ZIP CODE  \
# 0                        A1       4455 PARK AVENUE              NaN   10457.0
# 1                        A1       4451 PARK AVENUE              NaN   10457.0
# 4                        A9    2327 WASHINGTON AVE              NaN   10458.0
# 5                        B1  482 CLAREMONT PARKWAY              NaN   10457.0
# 8                        B1          3854 3 AVENUE              NaN   10457.0
#
#   RESIDENTIAL UNITS  COMMERCIAL UNITS TOTAL UNITS LAND SQUARE FEET  \
# ...

# %%
data_out1.to_csv('data/data2.csv')

# %%
CombinedData = pd.concat([pd.read_csv(f) for f in glob.glob('data/*.csv')], ignore_index = True, sort=False )
CombinedData.head()
# Out:
#    Unnamed: 0  BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY   BLOCK    LOT  \
# 0           0      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   65.0
# 1           1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3030.0   67.0
# 2           4      2.0     BATHGATE  01 ONE FAMILY DWELLINGS  3039.0   29.0
# 3           5      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2912.0  130.0
# 4           8      2.0     BATHGATE  02 TWO FAMILY DWELLINGS  2929.0  114.0
#
#   BUILDING CLASS AT PRESENT                ADDRESS APARTMENT NUMBER  ZIP CODE  \
# 0                        A1       4455 PARK AVENUE              NaN   10457.0
# 1                        A1       4451 PARK AVENUE              NaN   10457.0
# 2                        A9    2327 WASHINGTON AVE              NaN   10458.0
# 3                        B1  482 CLAREMONT PARKWAY              NaN   10457.0
# 4                        B1          3854 3 AVENUE              NaN   10457.0
#
# ...

# %%
CombinedData.to_csv('../data/CombinedData.csv')

# %%
CombinedData.dtypes
# Out:
# Unnamed: 0                           int64
# BOROUGH                            float64
# NEIGHBORHOOD                        object
# BUILDING CLASS CATEGORY             object
# BLOCK                              float64
# LOT                                float64
# BUILDING CLASS AT PRESENT           object
# ADDRESS                             object
# APARTMENT NUMBER                    object
# ZIP CODE                           float64
# RESIDENTIAL UNITS                   object
# COMMERCIAL UNITS                   float64
# TOTAL UNITS                         object
# LAND SQUARE FEET                    object
# GROSS SQUARE FEET                   object
# YEAR BUILT                         float64
# TAX CLASS AT TIME OF SALE          float64
# BUILDING CLASS AT TIME OF SALE      object
#  SALE PRICE                         object
# SALEDATE                            object
# BUILDING CLASS AS OF FINAL ROLL     object
# SALE PRICE                         float64
# ...

# %%
CombinedData.count()
# Out:
# Unnamed: 0                         373179
# Unnamed: 0.1                       373179
# BOROUGH                            373179
# NEIGHBORHOOD                       373179
# BUILDING CLASS CATEGORY            373179
# BLOCK                              373179
# LOT                                373179
# BUILDING CLASS AT PRESENT           28092
# ADDRESS                            373179
# APARTMENT NUMBER                    81379
# ZIP CODE                           373164
# RESIDENTIAL UNITS                  350745
# COMMERCIAL UNITS                   345711
# TOTAL UNITS                        351475
# LAND SQUARE FEET                   344979
# GROSS SQUARE FEET                  344982
# YEAR BUILT                         365688
# TAX CLASS AT TIME OF SALE          373179
# BUILDING CLASS AT TIME OF SALE     373179
#  SALE PRICE                         28120
# SALEDATE                           373179
# BUILDING CLASS AS OF FINAL ROLL    341199
# ...

# %%
CombinedData = pd.read_csv("../data/CombinedData.csv")

# %%
# Out:
#    Unnamed: 0  Unnamed: 0.1  BOROUGH NEIGHBORHOOD  BUILDING CLASS CATEGORY  \
# 0           0             0      2.0     BATHGATE  01 ONE FAMILY DWELLINGS
# 1           1             1      2.0     BATHGATE  01 ONE FAMILY DWELLINGS
# 2           2             4      2.0     BATHGATE  01 ONE FAMILY DWELLINGS
# 3           3             5      2.0     BATHGATE  02 TWO FAMILY DWELLINGS
# 4           4             8      2.0     BATHGATE  02 TWO FAMILY DWELLINGS
#
#     BLOCK    LOT BUILDING CLASS AT PRESENT                ADDRESS  \
# 0  3030.0   65.0                        A1       4455 PARK AVENUE
# 1  3030.0   67.0                        A1       4451 PARK AVENUE
# 2  3039.0   29.0                        A9    2327 WASHINGTON AVE
# 3  2912.0  130.0                        B1  482 CLAREMONT PARKWAY
# 4  2929.0  114.0                        B1          3854 3 AVENUE
#
#   APARTMENT NUMBER  ...  LAND SQUARE FEET GROSS SQUARE FEET  YEAR BUILT  \
# ...

# %%
CombinedData['BOROUGH']=CombinedData['BOROUGH'].map(lambda x: int(x))
CombinedData['ZIP CODE']=CombinedData['ZIP CODE'].map(lambda x: int(x))
CombinedData.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-bb1fffdaaa23> in <module>
#       1 # CombinedData['BOROUGH']=CombinedData['BOROUGH'].map(lambda x: int(x))
# ----> 2 CombinedData['ZIP CODE']=CombinedData['ZIP CODE'].map(lambda x: int(x))
#       3 CombinedData.head()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    3823         dtype: object
#    3824         """
# -> 3825         new_values = super()._map_values(arg, na_action=na_action)
#    3826         return self._constructor(new_values, index=self.index).__finalize__(self)
#    3827
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#    1298
#    1299         # mapper is a function
# -> 1300         new_values = map_f(values, mapper)
#    1301
#    1302         return new_values
#
# ...
